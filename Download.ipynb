# %%
from tensorflow.keras.models import load_model

model = load_model("handwritten_character_model (1).h5")

print("Model Loaded Successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model Loaded Successfully!

# %%
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(_, _), (X_test, _) = mnist.load_data()

# Normalize the image data to values between 0 and 1
X_test = X_test / 255.0

# Reshape the data to add a channel dimension, as expected by the model (28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

print("MNIST test data loaded and preprocessed.")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# MNIST test data loaded and preprocessed.
